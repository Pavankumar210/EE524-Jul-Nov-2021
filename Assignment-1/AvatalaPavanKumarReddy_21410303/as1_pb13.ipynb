# %% [markdown]
# # Straight line

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(range(-10,11))
y=3*x+2
plt.plot(x,y,'m')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Straight line\ny=3x+2')
plt.show()
